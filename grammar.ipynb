# %%
from lark import Lark
from ast import *
from x86_ast import *

# %%
tokens = Lark("""
start: INT
INT: DIGIT+
DIGIT: /[0-9]/""")

# %%
print(tokens.parse("123"))
# Out:
# Tree(Token('RULE', 'start'), [Token('INT', '123')])
